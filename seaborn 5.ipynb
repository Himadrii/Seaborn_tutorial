# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sales=pd.read_csv("C:/Users/Himadri/Desktop/SampleSuperstore.csv")

# %%
sales.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
sns.distplot(sales.Sales)

# %%
sns.distplot(sales.Profit)

# %%
sns.distplot(sales.Profit,hist=False)

# %%
sns.distplot(sales.Profit,hist=False,rug=True)

# %%
sns.distplot(sales.Profit,rug=True,bins=100)

# %%
sns.distplot(sales.Profit[(sales.Region=="West")&(sales.Profit>0)],rug=True,bins=100)

# %%
from scipy import stats

# %%
a=np.random.gamma(6,size=200)

# %%
sns.distplot(a)

# %%
sales.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
sns.jointplot('Sales','Profit',data=sales)

# %%
sns.jointplot('Sales','Discount',data=sales)

# %%
sns.jointplot('Sales','Discount',data=sales,kind='hex')

# %%
sns.jointplot('Sales','Discount',data=sales,kind='kde')

# %%
sns.pairplot(sales)

# %%
sns.pairplot(sales,hue='Quantity')
